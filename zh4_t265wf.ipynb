# %% [markdown]
# 1. Jelenítsük meg minden egyes szoba esetén, hogy hányszor foglalták le!
#
# Csak a szoba azonosítója és a foglalások darabszáma jelenjen meg
# Azok a szobák is jelenjenek meg, ahol nem történt foglalás

# %%
SELECT 
    SZOBA.SZOBA_SZAMA AS SzobaAzonosito, 
    COUNT(FOGLALAS.SZOBA_FK) AS FoglalasokSzama
FROM 
    SZOBA
LEFT JOIN 
    FOGLALAS ON SZOBA.SZOBA_SZAMA = FOGLALAS.SZOBA_FK
GROUP BY 
    SZOBA.SZOBA_SZAMA
ORDER BY 
    SZOBA.SZOBA_SZAMA;

# %% [markdown]
# |SzobaAzonosito|FoglalasokSzama|
# |---|---|
# |1|160|
# |10|48|
# |11|40|
# |12|90|
# |13|28|
# |14|21|
# |15|42|
# |16|25|
# |17|30|
# |18|30|
# |19|30|
# |2|80|
# |20|25|
# |21|16|
# |22|24|
# |23|12|
# |24|12|
# |25|8|
# |26|6|
# |27|21|
# |28|18|
# |29|18|
# |3|160|
# |30|9|
# |31|9|
# |32|3|
# |33|18|
# |34|12|
# |35|27|
# |36|12|
# |37|6|
# |38|16|
# |39|14|
# |4|114|
# |40|4|
# |41|2|
# |42|6|
# |43|8|
# |44|6|
# |45|5|
# |46|4|
# |47|2|
# |48|9|
# |49|7|
# |5|64|
# |50|4|
# |6|84|
# |7|78|
# |8|65|
# |9|72|

# %% [markdown]
# 2. Listázzuk azon vendégek adatait, akik a legtöbb férőhelyes szobát (vagy szobákat) már lefoglalták!
#
# Csak klímás szoba jöhet számításba

# %%
SELECT V.*
FROM VENDEG V
JOIN FOGLALAS F ON V.USERNEV = F.UGYFEL_FK
JOIN SZOBA S ON F.SZOBA_FK = S.SZOBA_SZAMA
WHERE S.KLIMAS = 'i'
AND S.FEROHELY = (
    SELECT MAX(S1.FEROHELY)
    FROM SZOBA S1
    WHERE S1.KLIMAS = 'i'
);

# %% [markdown]
# |USERNEV|NEV|EMAIL|SZAML_CIM|SZUL_DAT|
# |---|---|---|---|---|
# |PETERB|Berendi P&#233;ter|p&#233;ter.berendi@mail.hu|3980 S&#225;toralja&#250;jhely Vas&#250;t utca 4/10.|1969-01-01|
# |henrik3|N&#225;dudvari Henrik|henrik.n&#225;dudvari@mail.hu|1077 Budapest Tan&#225;csk&#246;zt&#225;rsas&#225;g t&#233;r 1.|1986-12-05|
# |brigitta|Sz&#233;kely Brigitta|brigitta.sz&#233;kely@mail.hu|2462 Martonv&#225;s&#225;r Fő utca 47.|1978-09-13|
# |sara|Farkas S&#225;ra|s&#225;ra.farkas@mail.hu|5940 T&#243;tkoml&#243;s Felszabadul&#225;s utca 32.|1973-04-05|
# |LASZLOA|Antal L&#225;szl&#243;|l&#225;szl&#243;.antal@mail.hu|2484 Ag&#225;rd B&#233;csi utca 82.|1969-06-29|

# %% [markdown]
# 3. Jelenítsük meg, hogy az egyes szálláshelyek szobáit esetén a legutolsó 5 foglalás átlagosan hány főre történt!
#
# A számításnál vegyük figyelembe a felnőtteket és a gyermekeket is
# A foglalás dátumánál a METTOL mezőt használjuk

# %%
WITH LAST_FIVE AS (
    SELECT 
        SZOBA_FK, 
        GYERMEK_SZAM + FELNOTT_SZAM AS OSSZESEN,
        ROW_NUMBER() OVER (PARTITION BY SZOBA_FK ORDER BY METTOL DESC) AS f
    FROM FOGLALAS
)
SELECT 
    SZOBA_FK, 
    AVG(OSSZESEN) AS ATLAG
FROM LAST_FIVE
WHERE f <= 5
GROUP BY SZOBA_FK;

# %% [markdown]
# |SZOBA_FK|ATLAG|
# |---|---|
# |1|2|
# |2|3|
# |3|2|
# |4|1|
# |5|1|
# |6|2|
# |7|1|
# |8|2|
# |9|3|
# |10|2|
# |11|2|
# |12|2|
# |13|2|
# |14|3|
# |15|2|
# |16|3|
# |17|2|
# |18|3|
# |19|2|
# |20|2|
# |21|2|
# |22|3|
# |23|1|
# |24|3|
# |25|3|
# |26|2|
# |27|3|
# |28|2|
# |29|1|
# |30|2|
# |31|4|
# |32|2|
# |33|2|
# |34|2|
# |35|1|
# |36|3|
# |37|1|
# |38|2|
# |39|2|
# |40|2|
# |41|3|
# |42|2|
# |43|2|
# |44|3|
# |45|1|
# |46|2|
# |47|1|
# |48|2|
# |49|2|
# |50|1|
# |51|2|
# |52|1|
# |53|2|
# |54|2|
# |55|3|
# |56|1|
# |57|1|
# |58|2|
# |59|2|
# |60|2|
# |61|2|
# |62|1|
# |63|1|
# |64|2|
# |65|2|
# |66|3|
# |67|3|
# |68|4|
# |69|2|
# |70|2|
# |71|2|
# |72|1|
# |73|2|
# |74|3|
# |75|2|
# |76|1|
# |77|2|
# |78|2|
# |79|2|
# |80|2|
# |81|1|
# |82|2|
# |83|2|
# |84|1|
# |85|2|
# |86|2|
# |87|2|
# |88|2|
# |89|2|
# |90|2|
# |91|1|
# |92|3|
# |93|3|
# |94|1|
# |95|1|
# |96|2|
# |97|2|
# |98|1|
# |99|2|
# |100|2|
# |101|2|
# |102|1|
# |103|2|
# |104|2|
# |105|2|
# |106|1|
# |107|2|
# |108|1|
# |109|2|
# |110|1|
# |111|2|
# |112|3|
# |113|4|
# |114|2|
# |115|2|
# |116|2|
# |117|3|
# |118|2|
# |119|1|
# |120|2|
# |121|2|
# |122|3|
# |123|2|
# |124|2|
# |125|3|
# |126|1|
# |127|2|
# |128|2|
# |129|2|
# |130|1|
# |131|1|
# |132|2|
# |133|2|
# |134|2|
# |135|2|
# |136|1|
# |137|2|
# |138|2|
# |139|2|
# |140|2|
# |141|2|
# |142|2|
# |143|3|
# |144|3|
# |145|2|
# |146|2|
# |147|2|
# |148|1|
# |149|1|
# |150|2|
# |151|1|
# |152|2|
# |153|2|
# |154|2|
# |155|2|
# |156|3|
# |157|1|
# |158|3|
# |160|3|
# |161|2|
# |162|2|
# |163|1|
# |164|2|
# |165|1|
# |166|2|
# |167|2|
# |168|3|
# |169|2|
# |170|1|
# |171|1|
# |172|1|
# |173|1|
# |174|1|
# |175|1|
# |176|3|
# |177|3|
# |178|3|
# |179|3|
# |180|3|
# |181|3|
# |182|1|
# |183|2|
# |184|1|
# |185|3|
# |186|3|
# |187|2|
# |188|2|
# |189|2|
# |190|1|
# |191|2|
# |192|2|
# |193|4|
# |194|3|
# |195|1|
# |196|2|
# |197|2|
# |198|2|

# %% [markdown]
# 4. Készítsen lekérdezést, amely megjeleníti, hogy szálláshelyenként, azon belül a pótágyak száma szerint hány főre foglaltak összesen (felnőtt + gyermek)!
#
# Jelenjenek meg a részösszegek és a végösszeg is!

# %%
WITH Reserves AS (
    SELECT 
        SZALLASHELY.SZALLAS_NEV,
        SZOBA.POTAGY,
        (FOGLALAS.FELNOTT_SZAM + FOGLALAS.GYERMEK_SZAM) AS FOGLALAS_FO
    FROM 
        SZALLASHELY
    JOIN 
        SZOBA ON SZALLASHELY.SZALLAS_ID = SZOBA.SZALLAS_FK
    JOIN 
        FOGLALAS ON SZOBA.SZOBA_SZAMA = FOGLALAS.SZOBA_FK
)
SELECT 
    SZALLAS_NEV,
    POTAGY,
    SUM(FOGLALAS_FO) AS OsszesFo,
    GROUPING(SZALLAS_NEV) AS Szallas,
    GROUPING(POTAGY) AS Potagyasok
FROM 
    Reserves
GROUP BY 
    ROLLUP(SZALLAS_NEV, POTAGY)
ORDER BY 
    SZALLAS_NEV,
    POTAGY;

# %% [markdown]
# |SZALLAS_NEV|POTAGY|OsszesFo|Szallas|Potagyasok|
# |---|---|---|---|---|
# |NULL|NULL|3980|1|1|
# |Bagoly Hotel|NULL|281|0|1|
# |Bagoly Hotel|0|173|0|0|
# |Bagoly Hotel|1|94|0|0|
# |Bagoly Hotel|2|14|0|0|
# |Csal&#225;di H&#225;z|NULL|66|0|1|
# |Csal&#225;di H&#225;z|0|17|0|0|
# |Csal&#225;di H&#225;z|1|34|0|0|
# |Csal&#225;di H&#225;z|2|15|0|0|
# |Fortuna Apartman|NULL|164|0|1|
# |Fortuna Apartman|0|44|0|0|
# |Fortuna Apartman|1|91|0|0|
# |Fortuna Apartman|2|29|0|0|
# |Fortuna Panzi&#243;|NULL|340|0|1|
# |Fortuna Panzi&#243;|0|156|0|0|
# |Fortuna panzi&#243;|1|143|0|0|
# |Fortuna panzi&#243;|2|41|0|0|
# |Gold Hotel|NULL|641|0|1|
# |Gold Hotel|0|321|0|0|
# |Gold Hotel|1|194|0|0|
# |Gold Hotel|2|126|0|0|
# |Hotel H&#225;rom Hatty&#250;|NULL|508|0|1|
# |Hotel H&#225;rom Hatty&#250;|0|220|0|0|
# |Hotel H&#225;rom Hatty&#250;|1|249|0|0|
# |Hotel H&#225;rom Hatty&#250;|2|39|0|0|
# |J&#225;de panzi&#243;|NULL|73|0|1|
# |J&#225;de panzi&#243;|0|73|0|0|
# |Kentaur Hotel|NULL|446|0|1|
# |Kentaur Hotel|0|241|0|0|
# |Kentaur Hotel|1|172|0|0|
# |Kentaur Hotel|2|33|0|0|
# |Koll&#233;gium|NULL|137|0|1|
# |Koll&#233;gium|0|54|0|0|
# |Koll&#233;gium|1|83|0|0|
# |Lag&#250;na Hotel|NULL|331|0|1|
# |Lag&#250;na Hotel|0|165|0|0|
# |Lag&#250;na Hotel|1|139|0|0|
# |Lag&#250;na Hotel|2|27|0|0|
# |Ny&#225;rf&#225;s Vend&#233;gh&#225;z|NULL|132|0|1|
# |Ny&#225;rf&#225;s Vend&#233;gh&#225;z|0|95|0|0|
# |Ny&#225;rf&#225;s Vend&#233;gh&#225;z|1|17|0|0|
# |Ny&#225;rf&#225;s Vend&#233;gh&#225;z|2|20|0|0|
# |Partisz&#233;l Vend&#233;gh&#225;z|NULL|73|0|1|
# |Partisz&#233;l Vend&#233;gh&#225;z|0|41|0|0|
# |Partisz&#233;l Vend&#233;gh&#225;z|1|17|0|0|
# |Partisz&#233;l Vend&#233;gh&#225;z|2|15|0|0|
# |Rivi&#233;ra Panzi&#243;|NULL|166|0|1|
# |Rivi&#233;ra Panzi&#243;|0|60|0|0|
# |Rivi&#233;ra Panzi&#243;|1|106|0|0|
# |S&#225;ba-H&#225;z|NULL|166|0|1|
# |S&#225;ba-H&#225;z|0|67|0|0|
# |S&#225;ba-H&#225;z|1|99|0|0|
# |Szarvas Hotel|NULL|203|0|1|
# |Szarvas Hotel|0|106|0|0|
# |Szarvas Hotel|1|66|0|0|
# |Szarvas Hotel|2|31|0|0|
# |Szieszta Apartmanh&#225;z|NULL|87|0|1|
# |Szieszta Apartmanh&#225;z|0|55|0|0|
# |Szieszta Apartmanh&#225;z|1|32|0|0|
# |T&#237;m&#225;rh&#225;z Panzi&#243;|NULL|166|0|1|
# |T&#237;m&#225;rh&#225;z Panzi&#243;|0|80|0|0|
# |T&#237;m&#225;rh&#225;z Panzi&#243;|1|55|0|0|
# |T&#237;m&#225;rh&#225;z Panzi&#243;|2|31|0|0|

# %% [markdown]
# 5. Készítsünk ideiglenes táblát #MASKED_GUEST néven, ahol
#
# a tábla felépítése megegyezik a vendég tábláéval, DE
# a vendégek nevének csak az első 2, és az utolsó 3 karaktere jelenjen meg, közötte X-ek legyenek!

# %%
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE #MASKED_GUEST(
	[USERNEV] [nvarchar](20) NOT NULL,
	[NEV] [nvarchar](50) NOT NULL,
	[EMAIL] [nvarchar](60) NOT NULL,
	[SZAML_CIM] [nvarchar](100) NULL,
	[SZUL_DAT] [date] NULL,
 CONSTRAINT [PK_Vendeg] PRIMARY KEY CLUSTERED 
(
	[USERNEV] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

# %%
INSERT INTO #MASKED_GUEST (USERNEV, NEV, EMAIL, SZAML_CIM, SZUL_DAT)
SELECT 
    USERNEV, 
    CASE 
        WHEN LEN(NEV) <= 5 THEN NEV
        ELSE LEFT(NEV, 2) + REPLICATE('X', LEN(NEV) - 5) + RIGHT(NEV, 3)
    END AS NEV,
    EMAIL,
    SZAML_CIM,
    SZUL_DAT
FROM [dbo].[Vendeg];

# %%
SELECT * FROM #MASKED_GUEST;

# %% [markdown]
# |USERNEV|NEV|EMAIL|SZAML_CIM|SZUL_DAT|
# |---|---|---|---|---|
# |adam1|KiXXXXd&#225;m|&#225;d&#225;m.kiss@mail.hu|5630 B&#233;k&#233;s Szolnoki &#250;t 8.|1991-12-28|
# |adam3|BaXXXXXXXd&#225;m|adam3@gmail.com|3910 Tokaj D&#243;zsa Gy&#246;rgy utca 37.|1970-06-07|
# |adam4|BiXXXXXXXd&#225;m|&#225;d&#225;m.bieniek@mail.hu|8630 Balatonbogl&#225;r Juh&#225;szf&#246;ldi &#250;t 1.|1976-08-01|
# |agnes|LeXXXXXXXXnes|agnes@gmail.com|5200 T&#246;r&#246;kszentmikl&#243;s De&#225;k Ferenc &#250;t 5.|1979-12-10|
# |agnes3|HaXXXXXXXXXXXXnes|agnes3@gmail.com|6430 B&#225;csalm&#225;s Posta k&#246;z 2.|1967-04-11|
# |AGNESH|HoXXXXXXXXnes|AGNESH@gmail.com|8200 Veszpr&#233;m R&#225;k&#243;czi utca 21.|1981-12-24|
# |AGNESK|KoXXXXXXXnes|AGNESK@gmail.com|1084 Budapest Endrődi S&#225;ndor utca 47.|1988-10-02|
# |akos|B&#237;XXXXkos|&#225;kos.b&#237;r&#243;@mail.hu|9023 Győr Kossuth Lajos utca 47/b.|1982-04-24|
# |aladar|DuXXXXXXXd&#225;r|alad&#225;r.dunai@mail.hu|5931 Nagysz&#233;n&#225;s &#193;rp&#225;d utca 23.|1980-11-01|
# |alexandra|BaXXXXXXXXXXXXXdra|alexandra.bag&#243;czki@mail.hu|2381 T&#225;borfalva Petőfi utca 1/2.|1992-03-25|
# |andi|MaXXXXXXXXrea|andrea.mar&#243;di@mail.hu|5465 Cserkeszőlő &#193;rp&#225;d utca 4.|1968-05-07|
# |andras2|T&#243;XXXXXXr&#225;s|andr&#225;s.t&#243;th@mail.hu|4071 Egyek Petőfi utca 30.|1997-10-31|
# |andras21|MoXXXXXXXXr&#225;s|andr&#225;s.moln&#225;r@mail.hu|7900 Szigetv&#225;r R&#225;k&#243;czi utca 67.|1977-11-16|
# |andras3|V&#237;XXXXXXr&#225;s|andr&#225;s.v&#237;gh@mail.hu|1118 Budapest Arany J&#225;nos utca 1.|1971-04-02|
# |andras4|BaXXXXXXr&#225;s|andras4@gmail.com|3783 Edel&#233;ny Fő &#250;t 169.|1984-04-07|
# |andras41|KoXXXXXXXXXr&#225;s|andras41@gmail.com|5065 Nagyk&#246;rű Kossuth &#250;t 24.|1997-10-25|
# |ANDRASE|ErXXXXXXXr&#225;s|ANDRASE@gmail.com|5071 Besenysz&#246;g Szolnoki &#250;t 8.|1997-05-29|
# |ANDRASN|NaXXXXXXr&#225;s|andr&#225;s.nagy@mail.hu|6500 Baja Fő &#250;t 169.|1980-09-05|
# |andrea|KiXXXXXXrea|andrea.kiss@mail.hu|1113 Budapest Petőfi S&#225;ndor utca 87.|1993-03-25|
# |andrea3|SzXXXXXXXXrea|andrea3@gmail.com|7960 Sellye B&#233;csi utca 82.|1996-05-10|
# |andrea4|NeXXXXXXXXrea|andrea4@gmail.com|1124 Budapest Kiss u. 8.|1981-05-17|
# |ANDREAT|ToXXXXXXXXXrea|ANDREAT@gmail.com|6131 Szank B&#233;csi utca 82.|1986-11-14|
# |anett3|PiXXXXXXXXXett|anett.pivarcsi@mail.hu|1149 Budapest Fő &#250;t 60.|1967-01-03|
# |aniko|T&#243;XXXXXik&#243;|aniko@gmail.com|2085 Pilisv&#246;r&#246;sv&#225;r De&#225;k Ferenc &#250;t 5.|1973-06-03|
# |aniko4|B&#246;XXXXXXXik&#243;|aniko4@gmail.com|2484 Ag&#225;rd Petőfi S&#225;ndor t&#233;r 1.|1978-03-26|
# |ANIKOS|SiXXXXXXik&#243;|ANIKOS@gmail.com|5137 J&#225;szkis&#233;r B&#233;csi utca 82.|1988-12-14|
# |anita|HaXXXXXXXXXXXXXXita|anita.hamvay-kov&#225;cs@mail.hu|7220 Sarkad T&#225;ncsics utca 19.|1971-03-20|
# |annamaria1|SzXXXXXXXXXXria|annam&#225;ria.szűcs@mail.hu|1191 Budapest Rendeki utca 21.|1990-04-27|
# |ANNAMARIAR|ReXXXXXXXXXXria|ANNAMARIAR@gmail.com|8283 K&#225;ptalant&#243;ti Petőfi S&#225;ndor t&#233;r 1.|1977-09-26|
# |aron2|JaXXXXXron|aron2@gmail.com|7133 Fadd Bajcsy-Zsilinszky utca 4.|1971-04-26|
# |ARONK|KeXXXXXXXron|&#225;ron.kelemen@mail.hu|8200 Veszpr&#233;m Petőfi utca 8.|1989-08-10|
# |arpad2|&#214;tXXXXXXp&#225;d|&#225;rp&#225;d.&#246;tv&#246;s@mail.hu|2600 V&#225;c Padragi &#250;t 158.|1990-06-08|
# |ARPADH|HoXXXXXXXXp&#225;d|&#225;rp&#225;d.horv&#225;th@mail.hu|7349 Sz&#225;szv&#225;r D&#243;zsa Gy&#246;rgy u. 1.|1990-05-18|
# |ARPADM|M&#243;XXXXXXXp&#225;d|&#225;rp&#225;d.m&#243;ricz@mail.hu|3910 Tokaj R&#225;k&#243;czi utca 67.|1986-04-20|
# |attila|CsXXXXXXXila|attila@gmail.com|3000 Hatvan Bajcsy-Zsilinszky utca 4.|1979-12-25|
# |attila1|GuXXXXXXXXila|attila.guly&#225;s@mail.hu|3881 Aba&#250;jsz&#225;nt&#243; Szolnoki &#250;t 8.|1982-08-16|
# |attila4|BaXXXXXXXXila|attila.bar&#243;ti@mail.hu|7149 B&#225;ta Arany J&#225;nos utca 3.|1975-11-06|
# |ATTILAO|OpXXXXXXila|ATTILAO@gmail.com|8283 K&#225;ptalant&#243;ti R&#225;k&#243;czi &#250;t 200.|1995-05-08|
# |balazs1|BoXXXXXXXX&#225;zs|bal&#225;zs.bozsik@mail.hu|2300 R&#225;ckeve B&#233;csi utca 82.|1992-11-03|
# |balazs2|SzXXXXXXX&#225;zs|bal&#225;zs.szűcs@mail.hu|3170 Sz&#233;cs&#233;ny Szabads&#225;g utca 95.|1984-10-31|
# |balazs3|BaXXXXXXXX&#225;zs|balazs3@gmail.com|2131 G&#246;d Arany J&#225;nos utca 1.|1986-09-09|
# |balint|HoXXXXXXXXXint|balint@gmail.com|6646 T&#246;m&#246;rk&#233;ny Endrődi S&#225;ndor utca 47.|1996-03-17|
# |balint1|MoXXXXXXXXint|balint1@gmail.com|9181 Kimle Fő &#250;t 169.|1989-08-24|
# |balint2|VuXXXXXXXXXXXXXXint|balint2@gmail.com|2330 Dunaharaszti B&#233;ke utca 7.|1997-09-03|
# |balu|EnXXXXXXXXXint|b&#225;lint.endresz@mail.hu|3973 Cig&#225;nd Fő &#250;t 169.|1976-08-01|
# |beata4|BaXXXXX&#225;ta|be&#225;ta.bagi@mail.hu|8477 T&#252;skev&#225;r Felszabadul&#225;s utca 32.|1994-03-19|
# |BEATRIXK|KeXXXXXXXXXXrix|beatrix.ker&#233;nyi@mail.hu|7396 Magyarsz&#233;k Kossuth Lajos utca 47/b.|1972-04-06|
# |BEATRIXS|SzXXXXXXXXXXXrix|beatrix.szekendi@mail.hu|4060 Balmaz&#250;jv&#225;ros J&#225;szai t&#233;r 21.|1981-04-06|
# |BELAF|FaXXXXXX&#233;la|BELAF@gmail.com|5530 V&#233;sztő Petőfi S&#225;ndor utca 3.|1995-02-24|
# |bence|GyXXXXXXXXnce|bence@gmail.com|6900 Mak&#243; &#193;rp&#225;d utca 23.|1987-07-09|
# |BENCEB|BaXXXXXXXnce|bence.bajusz@mail.hu|8391 S&#225;rmell&#233;k Fő utca 56.|1973-06-21|
# |bernadett1|SiXXXXXXXXXXett|bernadett1@gmail.com|2300 R&#225;ckeve Fő utca 108.|1984-10-13|
# |bernadett2|KoXXXXXXXXXXXett|bernadett.kov&#225;cs@mail.hu|4200 Hajd&#250;szoboszl&#243; Fő &#250;t 122.|1996-08-20|
# |BERNADETTO|OrXXXXXXXXXXett|bernadett.orb&#225;n@mail.hu|5085 R&#225;k&#243;czifalva Arany J&#225;nos utca 1.|1987-12-07|
# |bertalan|CsXXXXXXXXXXlan|bertalan@gmail.com|1192 Budapest Fő &#250;t 169.|1977-10-15|
# |brigitta|SzXXXXXXXXXXXtta|brigitta.sz&#233;kely@mail.hu|2462 Martonv&#225;s&#225;r Fő utca 47.|1978-09-13|
# |brigitta3|PaXXXXXXXXXXtta|brigitta.pataki@mail.hu|2730 Albertirsa Rendeki utca 21.|1991-05-23|
# |csongor3|NaXXXXXXXXXXXXXgor|csongor.nagymih&#225;ly@mail.hu|9181 Kimle De&#225;k Ferenc &#250;t 5.|1984-03-05|
# |dani|V&#246;XXXXXXXiel|daniel@gmail.com|7150 Bonyh&#225;d D&#243;zsa Gy&#246;rgy u. 1.|1986-10-14|
# |daniel|R&#225;XXXXXXiel|d&#225;niel.r&#225;cz@mail.hu|9181 Kimle Szabads&#225;g t&#233;r 9.|1978-11-28|
# |daniel1|KeXXXXXXXXXiel|d&#225;niel.keszler@mail.hu|3580 Tisza&#250;jv&#225;ros Kossuth Lajos utca 6.|1969-07-16|
# |david|AmXXXXXXXvid|david@gmail.com|1149 Budapest Fő &#250;t 18.|1974-02-11|
# |david1|SoXXXXXXXvid|david1@gmail.com|5083 Kengyel Arany J&#225;nos utca 3.|1970-08-16|
# |david4|BeXXXXXXvid|david4@gmail.com|3500 Miskolc Balatoni &#250;t 12.|1990-10-08|
# |debora|BaXXXXXXX&#243;ra|deb&#243;ra.barna@mail.hu|1155 Budapest Fő &#250;t 169.|1976-10-14|
# |denes|T&#246;XXXXXXXXnes|denes@gmail.com|2400 Duna&#250;jv&#225;ros Kossuth &#250;t 39.|1975-03-14|
# |dora3|SaXXXXXX&#243;ra|d&#243;ra.sarodi@mail.hu|2855 Bokod Fő &#250;t 18.|1995-05-18|
# |edit|BiXXXXXXXXdit|edit.bittmann@mail.hu|6077 Orgov&#225;ny Fő utca 60.|1984-04-20|
# |emese|KuXXXXXXese|emese.kuruc@mail.hu|6700 Szeged R&#225;k&#243;czi utca 67.|1989-08-10|
# |eszter|MoXXXXXXXXter|eszter.moln&#225;r@mail.hu|6800 H&#243;dmezőv&#225;s&#225;rhely Fő &#250;t 77.|1987-05-10|
# |eszter2|BaXXXXXXXXter|eszter.balogh@mail.hu|6760 Kistelek Kossuth utca 11.|1998-01-31|
# |eszter4|F&#252;XXXXXXXter|eszter.f&#252;l&#246;p@mail.hu|3643 D&#233;destapolcs&#225;ny Kossuth Lajos utca 47/b.|1993-06-28|
# |ESZTERE|&#201;rXXXXXXXter|eszter.&#233;rsek@mail.hu|6785 Pusztam&#233;rges Kossuth Lajos utca 6.|1978-08-28|
# |eva|EnXXXXX&#201;va|eva@gmail.com|4231 B&#246;k&#246;ny Petőfi utca 8.|1967-06-30|
# |eva2|PeXXXXXXXX&#201;va|eva2@gmail.com|9653 R&#233;pcelak B&#233;csi utca 82.|1971-08-19|
# |EVAV|ViXXXXX&#201;va|EVAV@gmail.com|6913 Csan&#225;dpalota Arany J&#225;nos utca 3.|1980-12-26|
# |ferenc1|OrXXXXXXXenc|ferenc.orosz@mail.hu|5061 Tiszas&#252;ly Arany J&#225;nos utca 3.|1983-10-08|
# |fruzsina4|FrXXXXXXXXXina|fruzsina4@gmail.com|9700 Szombathely Szabads&#225;g utca 95.|1996-08-16|
# |gabor1|K&#246;XXXXXXbor|gabor1@gmail.com|6762 S&#225;ndorfalva &#193;rp&#225;d utca 23.|1973-07-15|
# |gabor4|TeXXXXXXbor|g&#225;bor.telek@mail.hu|9071 G&#246;rbeh&#225;za Fő &#250;t 169.|1987-03-15|
# |GABORS|SzXXXXXXXXXbor|GABORS@gmail.com|3630 Putnok Kossuth utca 27.|1990-05-31|
# |gabriella1|NaXXXXXXXXXlla|gabriella1@gmail.com|1077 Budapest Dob utca 1|1982-11-01|
# |gabriella10|ViXXXXXXXXXlla|gabriella10@gmail.com|2484 Ag&#225;rd Arany J&#225;nos utca 3.|1969-06-18|
# |georgij|NyXXXXXXXXgij|georgij.ny&#237;ri@mail.hu|8391 S&#225;rmell&#233;k Grassalkovich &#250;t 10.|1983-02-23|
# |gusztav|B&#225;XXXXXXXXt&#225;v|gusztav@gmail.com|3643 D&#233;destapolcs&#225;ny Endrődi S&#225;ndor utca 47.|1967-02-25|
# |GYONGYIK|KoXXXXXXXXXXgyi|gy&#246;ngyi.kornse&#233;@mail.hu|8800 Nagykanizsa Fő &#250;t 60.|1974-06-07|
# |GYORGYO|OrXXXXXXXXrgy|GYORGYO@gmail.com|7220 Sarkad D&#243;zsa Gy&#246;rgy u. 1.|1980-03-23|
# |henrik3|N&#225;XXXXXXXXXXXrik|henrik.n&#225;dudvari@mail.hu|1077 Budapest Tan&#225;csk&#246;zt&#225;rsas&#225;g t&#233;r 1.|1986-12-05|
# |IBOLYAA|AnXXXXXXXlya|ibolya.andor@mail.hu|9023 Győr Posta k&#246;z 2.|1983-11-27|
# |ilona3|BoXXXXXXXXona|ilona3@gmail.com|2483 G&#225;rdony Posta k&#246;z 2.|1990-08-06|
# |imre|B&#250;XXXXmre|imre.b&#250;za@mail.hu|9181 Kimle Petőfi S&#225;ndor t&#233;r 1.|1988-09-30|
# |imre1|PaXXXXmre|imre.papp@mail.hu|1077 Budapest Szolnoki &#250;t 8.|1976-06-25|
# |istvan|SoXXXXXXv&#225;n|istvan@gmail.com|2370 Dabas Kossuth utca 27.|1986-06-28|
# |istvan1|ViXXXXXXv&#225;n|istv&#225;n.vizi@mail.hu|7086 Ozora R&#225;k&#243;czi utca 1.|1997-12-01|
# |ISTVANV|VaXXXXXXXv&#225;n|ISTVANV@gmail.com|6320 Solt Hős&#246;k tere 11.|1989-04-09|
# |janos3|HaXXXXXXXXXXnos|janos3@gmail.com|8700 Marcali Petőfi S&#225;ndor t&#233;r 1.|1967-11-02|
# |JANOSG|GiXXXXXXXnos|JANOSG@gmail.com|3300 Eger De&#225;k Ferenc &#250;t 5.|1975-01-03|
# |JANOSP|P&#225;XXXXXXXXXnos|JANOSP@gmail.com|5920 Csorv&#225;s Padragi &#250;t 158.|1984-10-12|
# |jozsef|GeXXXXXXXXXsef|jozsef@gmail.com|6050 Lajosmizse Fő &#250;t 18.|1985-11-01|
# |jozsef2|VaXXXXXXXsef|j&#243;zsef.vajda@mail.hu|6700 Szeged Baracsi L&#225;szl&#243; utca 14.|1978-09-04|
# |JOZSEFG|GyXXXXXXXXsef|j&#243;zsef.gyuris@mail.hu|2660 Balassagyarmat Petőfi utca 1/2.|1975-05-26|
# |JUDITH|H&#237;XXXXXXXdit|JUDITH@gmail.com|2100 G&#246;d&#246;llő Fő &#250;t 169.|1997-07-12|
# |julia|T&#243;XXXXXlia|julia@gmail.com|5310 Kis&#250;jsz&#225;ll&#225;s &#193;rp&#225;d utca 4.|1993-03-02|
# |julia4|NaXXXXXlia|julia4@gmail.com|7000 S&#225;rbog&#225;rd J&#225;szai t&#233;r 21.|1985-08-11|
# |julianna4|SzXXXXXXXXXnna|julianna4@gmail.com|6700 Szeged Kossuth Lajos utca 6.|1990-09-29|
# |kata|GoXXXXXXXXXlin|katalin.gondos@mail.hu|8237 Tihany Kossuth Lajos utca 6.|1968-06-22|
# |katalin|HoXXXXXXXXXXlin|katalin.horv&#225;th@mail.hu|2424 Elősz&#225;ll&#225;s R&#225;k&#243;czi &#250;t 200.|1968-01-01|
# |katalin4|KeXXXXXXXXXXlin|katalin4@gmail.com|2800 Tatab&#225;nya B&#250;v&#225;r utca 4.|1986-04-13|
# |kati|ZaXXXXXXXXXlin|katalin.zatyk&#243;@mail.hu|7511 &#214;tv&#246;sk&#243;nyi Kossuth Lajos utca 6.|1995-05-01|
# |katka|KoXXXXXXXXXlin|katalin.kov&#225;cs@mail.hu|8254 Kőv&#225;g&#243;&#246;rs Petőfi utca 22.|1975-03-31|
# |klaudia2|BaXXXXXXXdia|klaudia.bak&#243;@mail.hu|8254 Kőv&#225;g&#243;&#246;rs Kossuth Lajos utca 6.|1982-04-16|
# |kornel4|LuXXXXXXXXn&#233;l|korn&#233;l.luk&#225;cs@mail.hu|2053 Herceghalom B&#233;csi utca 82.|1975-09-30|
# |kristof4|PoXXXXXXXXXXt&#243;f|kristof4@gmail.com|8220 Balatonalm&#225;di M&#233;sz&#225;ros utca 7.|1984-01-15|
# |kriszti|HoXXXXXXXXXXXXina|kriszti@gmail.com|6060 Tiszak&#233;cske &#193;rp&#225;d utca 4.|1978-06-12|
# |krisztian4|CzXXXXXXXXXXXi&#225;n|kriszti&#225;n.cz&#233;rna@mail.hu|1107 Budapest D&#243;zsa Gy&#246;rgy utca 37.|1970-08-01|
# |KRISZTIANM|MoXXXXXXXXXXXXXi&#225;n|KRISZTIANM@gmail.com|9155 L&#233;b&#233;ny J&#225;szai t&#233;r 21.|1968-05-27|
# |krisztina|SzXXXXXXXXXXXXina|krisztina@gmail.com|6646 T&#246;m&#246;rk&#233;ny Arany J&#225;nos utca 1.|1979-05-10|
# |krisztina1|BoXXXXXXXXXina|krisztina.bori@mail.hu|2115 V&#225;cszentl&#225;szl&#243; Fő utca 47.|1969-10-13|
# |KRISZTINAG|GyXXXXXXXXXXXXina|KRISZTINAG@gmail.com|6762 S&#225;ndorfalva Arany J&#225;nos utca 1.|1987-09-19|
# |lajos|KiXXXXXjos|lajos.kiss@mail.hu|1077 Budapest Dob utca 1|1978-10-31|
# |lala|NaXXXXXXXXXXXjos|lajos.nagymih&#225;ly@mail.hu|8638 Balatonlelle R&#225;k&#243;czi &#250;t 200.|1997-02-24|
# |laszlo1|FaXXXXXXXXzl&#243;|l&#225;szl&#243;.farkas@mail.hu|5200 T&#246;r&#246;kszentmikl&#243;s Rendeki utca 21.|1967-10-30|
# |laszlo2|M&#243;XXXXXXzl&#243;|l&#225;szl&#243;.m&#243;ra@mail.hu|9970 Szentgotth&#225;rd Petőfi utca 1/2.|1975-02-19|
# |LASZLOA|AnXXXXXXXzl&#243;|l&#225;szl&#243;.antal@mail.hu|2484 Ag&#225;rd B&#233;csi utca 82.|1969-06-29|
# |LASZLON|NaXXXXXXzl&#243;|l&#225;szl&#243;.nagy@mail.hu|1173 Budapest J&#225;szai t&#233;r 21.|1969-04-12|
# |maria1|BaXXXXXXXria|m&#225;ria.bar&#225;th@mail.hu|1047 Budapest Posta k&#246;z 2.|1995-11-19|
# |mark|KiXXXXXX&#225;rk|m&#225;rk.kisp&#225;l@mail.hu|1086 Budapest Juh&#225;szf&#246;ldi &#250;t 1.|1996-01-23|
# |MARKH|HoXXXXXXX&#225;rk|m&#225;rk.horv&#225;th@mail.hu|4400 Ny&#237;regyh&#225;za Badacsonyi utca 12.|1997-09-23|
# |marton|KaXXXXXXXXXton|marton@gmail.com|5137 J&#225;szkis&#233;r Fő &#250;t 169.|1989-06-24|
# |MATEK|KoXXXX&#225;t&#233;|m&#225;t&#233;.koza@mail.hu|1011 Budapest K&#246;zponti telep 3.|1997-02-28|
# |matyas2|BoXXXXXXXy&#225;s|matyas2@gmail.com|2700 Cegl&#233;d Kossuth Lajos utca 6.|1972-07-07|
# |MATYASS|SzXXXXXXXXXXy&#225;s|m&#225;ty&#225;s.szil&#225;gyi@mail.hu|9023 Győr Kossuth Lajos utca 6.|1975-03-22|
# |MIHALYJ|JuXXXXXXXX&#225;ly|mih&#225;ly.juh&#225;sz@mail.hu|6786 Ruzsa R&#225;k&#243;czi utca 1.|1979-10-12|
# |miklos2|GoXXXXXXXXl&#243;s|miklos2@gmail.com|2100 G&#246;d&#246;llő &#193;rp&#225;d utca 23.|1995-10-07|
# |MIKLOSB|BaXXXXXXXl&#243;s|mikl&#243;s.balla@mail.hu|4060 Balmaz&#250;jv&#225;ros Szent Istv&#225;n utca 2.|1979-02-16|
# |MONIKAM|MoXXXXXXXika|m&#243;nika.mohos@mail.hu|2241 S&#252;lys&#225;p Baracsi L&#225;szl&#243; utca 14.|1974-10-01|
# |NANDORF|FőXXXXdor|n&#225;ndor.fő@mail.hu|5920 Csorv&#225;s B&#233;csi utca 82.|1968-11-12|
# |nikolett3|HoXXXXXXXXXXXett|nikolett3@gmail.com|1072 Budapest Arany J&#225;nos utca 1.|1981-09-29|
# |nikoletta4|KőXXXXXXXtta|nikoletta4@gmail.com|5537 Zsad&#225;ny Fő &#250;t 18.|1972-01-10|
# |NIKOLETTAT|TaXXXXXXXXXXtta|nikoletta.tat&#225;r@mail.hu|1067 Budapest Győri utca 12.|1997-10-19|
# |norbert|SzXXXXXXXXert|norbert@gmail.com|5071 Besenysz&#246;g Győri utca 12.|1969-07-17|
# |norbert2|HeXXXXXXXXXXert|norbert.hegedűs@mail.hu|2081 Piliscsaba Rendeki utca 21.|1991-07-17|
# |norbert4|MiXXXXXXXert|norbert4@gmail.com|3973 Cig&#225;nd Bajcsy-Zsilinszky utca 4.|1983-06-15|
# |norbert5|B&#233;XXXXXXXXert|norbert5@gmail.com|8640 Fony&#243;d Bajcsy-Zsilinszky utca 4.|1975-07-27|
# |pal|BaXXXXXXP&#225;l|p&#225;l.barab&#225;s@mail.hu|1183 Budapest Szolnoki &#250;t 8.|1968-02-06|
# |peter1|KoXXXXXXter|peter1@gmail.com|6913 Csan&#225;dpalota K&#246;zponti telep 3.|1976-03-18|
# |peter2|BoXXXXXXter|peter2@gmail.com|4800 V&#225;s&#225;rosnam&#233;ny Zombori &#250;t 2/A|1976-01-26|
# |peter3|SzXXXXXXXter|peter3@gmail.com|1155 Budapest Arany J&#225;nos utca 3.|1983-07-18|
# |peter4|B&#237;XXXXXter|p&#233;ter.b&#237;r&#243;@mail.hu|5137 J&#225;szkis&#233;r R&#225;k&#243;czi utca 67.|1985-09-01|
# |PETERB|BeXXXXXXXXter|p&#233;ter.berendi@mail.hu|3980 S&#225;toralja&#250;jhely Vas&#250;t utca 4/10.|1969-01-01|
# |polla|PaXXXXXXXXlla|polla@gmail.com|2484 Ag&#225;rd Fő &#250;t 18.|1994-02-04|
# |rajmond4|R&#225;XXXXXXXond|rajmond.r&#225;cz@mail.hu|9155 L&#233;b&#233;ny Petőfi utca 1/2.|1993-09-25|
# |reka4|SzXXXXXXXX&#233;ka|r&#233;ka.szikszai@mail.hu|8254 Kőv&#225;g&#243;&#246;rs Templom utca 73.|1969-11-27|
# |RENATAK|KaXXXXXXXX&#225;ta|ren&#225;ta.kardos@mail.hu|7086 Ozora B&#233;csi utca 82.|1988-05-17|
# |RENATAS|SzXXXXXXXXX&#225;ta|RENATAS@gmail.com|2053 Herceghalom Kossuth utca 27.|1991-03-26|
# |robert2|PaXXXXXXXert|robert2@gmail.com|2370 Dabas R&#225;k&#243;czi utca 21.|1977-01-08|
# |ROBERTI|IvXXXXXXert|r&#243;bert.iv&#225;n@mail.hu|2377 &#214;rk&#233;ny Petőfi S&#225;ndor utca 3.|1967-07-02|
# |ROBERTP|P&#225;XXXXXXXXXert|ROBERTP@gmail.com|5137 J&#225;szkis&#233;r Ady Endre &#250;t 27.|1972-05-16|
# |roland|T&#243;XXXXXXand|roland@gmail.com|2000 Szentendre Fő &#250;t 169.|1968-03-21|
# |roland1|FeXXXXXXXXXand|roland.ferencz@mail.hu|2424 Elősz&#225;ll&#225;s Fő &#250;t 169.|1985-12-31|
# |roza2|BuXXXXXX&#243;za|roza2@gmail.com|5661 &#218;jk&#237;gy&#243;s Arany J&#225;nos utca 3.|1988-12-26|
# |sandor|KaXXXXXXXXdor|sandor@gmail.com|8283 K&#225;ptalant&#243;ti Kossuth Lajos utca 1/a.|1970-01-27|
# |sandor3|FaXXXXXXXXdor|s&#225;ndor.farkas@mail.hu|8640 Fony&#243;d Tan&#225;csk&#246;zt&#225;rsas&#225;g t&#233;r 1.|1989-01-27|
# |sandor4|NaXXXXXXdor|sandor4@gmail.com|4600 Kisv&#225;rda Fő utca 47.|1997-06-11|
# |sara|FaXXXXXX&#225;ra|s&#225;ra.farkas@mail.hu|5940 T&#243;tkoml&#243;s Felszabadul&#225;s utca 32.|1973-04-05|
# |SEBASTIANF|FoXXXXXXXXXXXXXi&#225;n|SEBASTIANF@gmail.com|7960 Sellye Grassalkovich &#250;t 10.|1992-09-09|
# |sebestyen|RaXXXXXXXXy&#233;n|sebestyen@gmail.com|7130 Tolna K&#246;zponti telep 3.|1992-03-03|
# |szabolcs|BoXXXXXXXXXlcs|szabolcs.bodor@mail.hu|6786 Ruzsa Ady Endre &#250;t 27.|1990-07-16|
# |SZABOLCSM|MiXXXXXXXXXXlcs|szabolcs.mikl&#243;s@mail.hu|1102 Budapest Fő &#250;t 169.|1980-08-11|
# |SZILARDS|SzXXXXXXXXX&#225;rd|szil&#225;rd.szalai@mail.hu|1077 Budapest Fő &#250;t 18.|1967-09-28|
# |szilvia1|TaXXXXXXXvia|szilvia.tari@mail.hu|6080 Szabadsz&#225;ll&#225;s B&#233;csi utca 82.|1971-03-09|
# |tamara2|MiXXXXXXXXara|tamara.mikl&#243;s@mail.hu|3910 Tokaj Kossuth &#250;t 39.|1980-08-11|
# |tamas|AnXXXXXXm&#225;s|tam&#225;s.antal@mail.hu|4440 Tiszavasv&#225;ri Posta k&#246;z 2.|1984-09-05|
# |TAMASF|F&#233;XXXXXXXm&#225;s|TAMASF@gmail.com|9023 Győr Arany J&#225;nos utca 1.|1997-11-06|
# |tibor|GoXXXXXXXbor|tibor.gombos@mail.hu|7100 Szeksz&#225;rd Kossuth utca 77.|1993-11-28|
# |tibor2|D&#225;XXXXXXXbor|tibor2@gmail.com|6646 T&#246;m&#246;rk&#233;ny &#193;rp&#225;d utca 23.|1985-02-02|
# |tihamer|KaXXXXXXXm&#233;r|tiham&#233;r.kazy@mail.hu|2370 Dabas Fő utca 60.|1991-07-05|
# |timea|PaXXXXXXmea|timea@gmail.com|1035 Budapest  Kossuth &#250;t 77.|1996-01-08|
# |timea2|DuXXXXXXmea|t&#237;mea.dusha@mail.hu|5920 Csorv&#225;s Kossuth utca 8.|1975-08-22|
# |tunde|TuXXXXXXXXnde|tunde@gmail.com|7130 Tolna Fő &#250;t 122.|1974-02-12|
# |valentin|FeXXXXXXXXtin|valentin.fer&#243;@mail.hu|3895 G&#246;nc B&#250;v&#225;r utca 4.|1986-01-09|
# |veronika4|TaXXXXXXXXXika|veronika4@gmail.com|6412 Balotasz&#225;ll&#225;s Rendeki utca 21.|1983-08-28|
# |VIKTORIAU|UrXXXXXXXXXria|viktoria.urb&#225;n@mail.hu|3860 Encs N&#233;pboltsor  2.|1996-05-03|
# |VIKTORK|KeXXXXXXXXXXXXtor|viktor.kereszt&#250;ri@mail.hu|2532 Tokodalt&#225;r&#243; Nagy Lajos t&#233;r 4.|1989-05-05|
# |vivien3|BoXXXXXXXien|vivien3@gmail.com|2117 Isaszeg Fő &#250;t 122.|1991-07-01|
# |zoltan|FoXXXXXXXt&#225;n|zolt&#225;n.fodor@mail.hu|3441 Mezőkeresztes Fő utca 23.|1979-11-25|
# |zoltan4|BaXXXXXXXt&#225;n|zoltan4@gmail.com|8313 Balatongy&#246;r&#246;k J&#225;szai t&#233;r 21.|1986-05-20|
# |ZOLTANP|PiXXXXXXXXt&#225;n|zolt&#225;n.pint&#233;r@mail.hu|6050 Lajosmizse Fő &#250;t 18.|1977-06-07|
# |ZOLTANT|T&#243;XXXXXXt&#225;n|zolt&#225;n.t&#243;th@mail.hu|4244 &#218;jfeh&#233;rt&#243; Posta k&#246;z 2.|1985-12-14|
# |zsofi1|MoXXXXXXX&#243;fi|zsofi1@gmail.com|2730 Albertirsa &#193;rp&#225;d utca 23.|1983-11-17|
# |zsolt1|PuXXXXXXolt|zsolt.pulai@mail.hu|8391 S&#225;rmell&#233;k Fő utca 60.|1988-05-27|
# |ZSOLTJ|J&#243;XXXXXXolt|ZSOLTJ@gmail.com|8315 Gyenesdi&#225;s Bajcsy-Zsilinszky utca 4.|1983-09-29|
# |zsuzsa|PuXXXXXXXXXXXXnna|zsuzsanna@gmail.com|6783 &#193;sotthalom Badacsonyi utca 12.|1980-09-17|
# |zsuzsa3|VaXXXXXXXXXXzsa|zsuzsa.vars&#225;nyi@mail.hu|8600 Si&#243;fok &#193;rp&#225;d utca 4.|1979-03-06|
# |zsuzsanna|BaXXXXXXXXXXnna|zsuzsanna.barta@mail.hu|4172 Biharnagybajom D&#243;zsa Gy&#246;rgy utca 37.|1994-10-07|
# |ZSUZSAV|VaXXXXXXXzsa|zsuzsa.vajda@mail.hu|6786 Ruzsa Kossuth utca 77.|1976-12-11|

# %% [markdown]
# 6. Valósítsa meg REDIS-ben a következő táblákat:
#
# IRO(ID, nev, nemzetiseg)
# KONYV(ID, cim, mufaj, IRO_ID)
# Vigyen fel táblánként legalább 2-2 sornyi adatot!

# %%
Connection string : redis-18809.c9.us-east-1-4.ec2.redns.redis-cloud.com:18809

HSET IRO:1 nev "Kiss Béla"
HSET IRO:1 nemzetiseg "magyar"

HSET IRO:2 nev "Nagy Árpád"
HSET IRO:2 nemzetiseg "színmagyar"

HSET KONYV:1 cim "Amerikai Pite"
HSET KONYV:1 mufaj "komédia"
HSET KONYV:1 IRO_ID 1

HSET KONYV:2 cim "Nők jogai"
HSET KONYV:2 mufaj "Fikció"
HSET KONYV:2 IRO_ID 2

# %% [markdown]
# 7. Cassandra CQL Shellben hozza létre a következő táblát:
#
#     STUDENT(ID, Nev, Teljesitett\_felevek, Eredmenyek, Nyelvtudas)
#
#     - Az ID legyen az elsődleges kulcs
#     - A Teljesitett félévek legyen LIST, tartalma egész számok, pl: 1, 2, 3
#     - Az Eredmenyek legyen MAP, tartalma, hogy melyik félévben mennyi volt az átlag, pl: 1: 3,00, 2: 4.55, 3: 4,10
#     - A Nyelvtudas legyen SET, tartalma a nyelvek megnevezése
#
#     Vigyen fel legalább 2 rekordot!

# %%
CREATE TABLE STUDENT (
    ID INT PRIMARY KEY,
    Nev TEXT,
    Teljesitett_felevek LIST<INT>,
    Eredmenyek MAP<INT, FLOAT>,
    Nyelvtudas SET<TEXT>
);

# %%
INSERT INTO STUDENT (ID, Nev, Teljesitett_felevek, Eredmenyek, Nyelvtudas) VALUES (1, 'Péter Árpád', [1, 3], {1: 2.00, 3: 4.55}, {'angol', 'német'});
INSERT INTO STUDENT (ID, Nev, Teljesitett_felevek, Eredmenyek, Nyelvtudas) VALUES (2, 'Magyar Péter', [2, 3], {2: 5.00, 3: 5.00}, {'francia', 'olasz'});

# %% [markdown]
# 8. A Neo4j Sandbox-ban vagy a Desktopban jelenítsük meg azon személyeket, akik egy filmben szerepeltek Tom Hanks-sel.
#
#     - Egy szereplő neve csak egyszer jelenjen meg
#     - Tom Hanks ne legyen benne a listában

# %%
MATCH (p1:Person)-[:ACTED_IN]->(:Movie)<-[:ACTED_IN]-(p2:Person)
WHERE p1.name = 'Tom Hanks' AND p1 <> p2
RETURN DISTINCT p2.name AS Színész
